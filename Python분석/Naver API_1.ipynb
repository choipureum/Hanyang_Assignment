# %%
# !pip install xlsxwriter
# Out:
# Requirement already satisfied: xlsxwriter in /anaconda3/lib/python3.7/site-packages (1.1.5)

# %%
import urllib.request

client_id = '---'
client_secret = "---"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)

response = urllib.request.urlopen(request)

# %%
response

# %%
response.getcode()
# Out:
# 200

# %%
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Fri, 22 Nov 2019 20:57:56 +0900",
# "total": 120609,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b>학원 답은 하나다!",
# "link": "https:\/\/blog.naver.com\/nr_yeon?Redirect=Log&logNo=221707634731",
# "description": "<b>파이썬</b>학원 답은 하나다! 컴공과를 나온 저는 사회로 진출하기 위하여 1년간 갖은 노력을 했어요!... <b>파이썬</b> 학원을 알아봤어요. 프로그래밍에 대한 기초를 제대로 배우기로 마음을 먹었죠. 많은 아카데미 중에서... ",
# "bloggername": "청춘로연",
# "bloggerlink": "https://blog.naver.com/nr_yeon",
# "postdate": "20191114"
#
# },
# {
# "title": "<b>파이썬</b> 웹 프로그래밍 장고 공부 예제소스",
# "link": "https:\/\/blog.naver.com\/rewq2505?Redirect=Log&logNo=221707028790",
# "description": "요즘 <b>파이썬</b> 웹 프로그래밍 공부하신느 분들 많더라구요 저 또한 웹개발에 관심이 많아서 이것저것 공부해보고 있는 중인데, 많은 분들이 Django를 활용한 <b>파이썬</b> 웹 프로그래밍 요 책을 많이... ",
# "bloggername": "보리언니의 소소한 일상",
# "bloggerlink": "https://blog.naver.com/rewq2505",
# "postdate": "20191113"
#
# },
# {
# "title": "금융권에 필요한 <b>파이썬</b> 스킬트리 #1.",
# "link": "https:\/\/blog.naver.com\/stochastic73?Redirect=Log&logNo=221574101454",
# "description": "금융권에 드리우는 <b>파이썬</b>의 어두운 그림자 만약 현재 금융권에서 일하고 있지만 코딩을 할 줄 모른다면?그 사람은 미래에 코딩을 할 수 있는 사람들에... blog.naver.com <b>파이썬</b> 그리고 코딩이라는 것이 점점... ",
# "bloggername": "Antifragile Domain",
# "bloggerlink": "https://blog.naver.com/stochastic73",
# "postdate": "20190630"
#
# },
# {
# "title": "코딩기초 <b>파이썬</b>학원 직접 다녀본 후기입니다",
# "link": "https:\/\/blog.naver.com\/designer_dh?Redirect=Log&logNo=221699076580",
# "description": "오늘은 <b>파이썬</b>학원 수강후기를 준비했어요 저는 고등학교 2학년으로 <b>파이썬</b>학원에서 진학준비를 하기위해서 수업을 들었습니다 나중에 대학을 가고 공부해서웹개발자로 취업하기 위해서 공부하고 있고... ",
# "bloggername": "부러진날개로 나는법을 배워라",
# "bloggerlink": "https://blog.naver.com/designer_dh",
# "postdate": "20191105"
#
# },
# {
# "title": "일취월장 <b>파이썬</b> 학원 달라진 경험!",
# "link": "https:\/\/blog.naver.com\/redrock27?Redirect=Log&logNo=221700209048",
# "description": "끝에 <b>파이썬</b> 학원으로 정할 수 있었습니다. 일단 상담 선생님도 매우 친절하셨고, 제가 원하는 교육을... 기초단계인 <b>파이썬</b>부터 시작하는 것이 좋겠다고 말씀하셨습니다. 해당 언어는 초보나 입문자도 어렵지... ",
# "bloggername": "스튜",
# "bloggerlink": "https://blog.naver.com/redrock27",
# "postdate": "20191107"
#
# },
# {
# "title": "<b>파이썬</b>인강과 학원의 차이, 직접수강해본 후기 알려드립니다",
# "link": "https:\/\/blog.naver.com\/cdh0584?Redirect=Log&logNo=221684600901",
# "description": "안녕하세요 IT멘토스쿨입니다 오늘은 <b>파이썬</b>인강 직접 수강해보고 쓰는 후기에 대해서... 얼마전에 <b>파이썬</b>인강을 수강했던 학생입니다. 우연히 접하게된 이룸이라는 사이트를 통해서 수강하면서 깊이... ",
# "bloggername": "부날파 : 부러진날개로파다닥 New",
# "bloggerlink": "https://blog.naver.com/cdh0584",
# "postdate": "20191021"
#
# },
# {
# "title": "한권으로 끝내는 <b>파이썬</b> - 독학으로 Python 프로그램 코딩... ",
# "link": "https:\/\/blog.naver.com\/since201109?Redirect=Log&logNo=221553965961",
# "description": "그때 처음 접한 언어가 <b>파이썬</b>(Python)이었습니다. 빅데이터나, 머신러닝, 딥러닝, AI(인공지능) 쪽에서는 스칼라 혹은 <b>파이썬</b> 기반으로 한 경우가 많았습니다! 예를 들면 구글의 인공지능 오픈소스인... ",
# "bloggername": "As a Programmer : SOA, Java, JSP, 안드로이드",
# "bloggerlink": "https://blog.naver.com/since201109",
# "postdate": "20190604"
#
# },
# {
# "title": "<b>파이썬</b> 강좌 - 2강#왜 <b>파이썬</b>인가?",
# "link": "https:\/\/blog.naver.com\/nkj2001?Redirect=Log&logNo=221656737848",
# "description": "이런 스타일이 <b>파이썬</b>의 강점인 가장 큰 부분이라고 생각합니다. Windows 파일 감시 인젝션 소스 코드 일부 왜 <b>파이썬</b>인가? 1. 가장 간결한 언어 (<b>파이썬</b> 제작자가 가장 의도한 부분) - 코드가 짧고 가독성이... ",
# "bloggername": "▒ Blog Of Life ▒",
# "bloggerlink": "https://blog.naver.com/nkj2001",
# "postdate": "20190923"
#
# },
# {
# "title": "<b>파이썬</b> 웹 프로그래밍 컴퓨터 공부 start!",
# "link": "https:\/\/blog.naver.com\/tw01554?Redirect=Log&logNo=221715152464",
# "description": "이용한다는 <b>파이썬</b> 웹 프로그래밍 책 이용해봤어요 딱 어떻게 제가 원하는 떄에 이렇게 받아 볼 수... 되었씁니다 <b>파이썬</b> 웹 프로그래밍 아무래도 이건 중급이라 어렵게 느낄 수 있어요 그래서 아예 아무것도... ",
# "bloggername": "헨2의 daily",
# "bloggerlink": "https://blog.naver.com/tw01554",
# "postdate": "20191122"
#
# },
# {
# "title": "<b>파이썬</b> 프로그래밍 - 개발 범위",
# "link": "https:\/\/blog.naver.com\/urmyver?Redirect=Log&logNo=221670828962",
# "description": "요즘 프로그래밍 언어 중에서 검색하는 량이 가장 많은 <b>파이썬</b> 프로그래밍 언어는 분야를 불문하고 다른 프로그래밍 언어에 비하여 쉬운 편이다 보니 <b>파이썬</b>을 공부하려는 경우가 계속 늘어나고 있다.... ",
# "bloggername": "주들의 그리 대단하진 않지만 굉장한 이야기",
# "bloggerlink": "https://blog.naver.com/urmyver",
# "postdate": "20191007"
#
# }
# ]
# }

# %%
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/book?query=" + encText
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)

response = urllib.request.urlopen(request)
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Fri, 22 Nov 2019 20:57:58 +0900",
# "total": 930,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b> (비전공자를위한 <b>파이썬</b> 기초 입문서,한 권으로 끝내는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14921665",
# "image": "https://bookthumb-phinf.pstatic.net/cover/149/216/14921665.jpg?type=m1&udate=20190514",
# "author": "김명호",
# "price": "18000",
# "discount": "16200",
# "publisher": "에듀웨이",
# "pubdate": "20190525",
# "isbn": "1186179368 9791186179369",
# "description": "막막했던 <b>파이썬</b>, 이제 한 권으로 기초를 배우는\n<b>파이썬</b> 사용 설명서!전 세계적으로 유명한 구글(GOOGLE)이 자신의 많은 서비스를 <b>파이썬</b>으로 제공하고 있습니다. 이것은 구글의 뛰어난 서비스를 개인의 비즈니스에 쉽게 이용할 수 있다는 의미입니다.  이러한 발전에 맞춰 <b>파이썬</b> 문법의 기초를 쉽게 이해할 수... "
#
# },
# {
# "title": "모두의 <b>파이썬</b> (20일 만에 배우는 프로그래밍 기초)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14126163",
# "image": "https://bookthumb-phinf.pstatic.net/cover/141/261/14126163.jpg?type=m1&udate=20181105",
# "author": "이승찬",
# "price": "12000",
# "discount": "10800",
# "publisher": "길벗",
# "pubdate": "20181009",
# "isbn": "1160505853 9791160505856",
# "description": "<b>파이썬</b> 분야 & 어린이 코딩 교육 분야\n2년 연속 베스트셀러! 개정판 출간!\n\n즐겁게 시작하는 나의 첫 프로그래밍!\n프로그래밍을 한 번도 해본 적이 없어도 괜찮다. <b>파이썬</b>이 무엇인지 몰라도 상관 없다.... 어느새 <b>파이썬</b> 프로그램으로 멋진 그림을 그리고, 계산을 하고, 간단한 게임을 만들고, 수학 문제를... "
#
# },
# {
# "title": "<b>파이썬</b>으로 데이터 주무르기 (독특한 예제를 통해 배우는 데이터 분석 입문)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12898027",
# "image": "https://bookthumb-phinf.pstatic.net/cover/128/980/12898027.jpg?type=m1&udate=20191023",
# "author": "민형기",
# "price": "27500",
# "discount": "24750",
# "publisher": "비제이퍼블릭",
# "pubdate": "20171229",
# "isbn": "1186697474 9791186697474",
# "description": "있을 <b>파이썬</b> 기초 문법책과 같은 내용이 아닌, 데이터 분석이라는 특별한 분야에서 초보를 위해 처음부터 끝까지 <b>파이썬</b>으로 진행되는 과정을 다룹니다. 서울시 범죄 현황 분석, 셀프 주유소 가격 정보 분석, 19대 대선 결과 분석 등 흥미 있는 목표를 이루기 위해서 <b>파이썬</b>의 기초를 익히고, 데이터를 다루고... "
#
# },
# {
# "title": "혼자 공부하는 <b>파이썬</b> (<b>파이썬</b> 최신 버전 반영)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15028688",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/286/15028688.jpg?type=m1&udate=20190614",
# "author": "윤인성",
# "price": "18000",
# "discount": "16200",
# "publisher": "한빛미디어",
# "pubdate": "20190610",
# "isbn": "1162241888 9791162241882",
# "description": "1:1 과외하듯 배우는 <b>파이썬</b> 프로그래밍 자습서(<b>파이썬</b> 최신 버전 반영)\n이 책은 독학으로 프로그래밍 언어를 처음 배우려는 입문자가, 혹은 <b>파이썬</b>을 배우려는 입문자가 ‘꼭 필요한 내용을 제대로’ 학습할 수 있도록 구성했다. ‘무엇을’, ‘어떻게’ 학습해야 할지조차 모르는 입문자의 막연한 마음을 살펴... "
#
# },
# {
# "title": "Do it! 점프 투 <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15052904",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/529/15052904.jpg?type=m1&udate=20190820",
# "author": "박응용",
# "price": "18800",
# "discount": "16920",
# "publisher": "이지스퍼블리싱",
# "pubdate": "20190620",
# "isbn": "1163030910 9791163030911",
# "description": "<b>파이썬</b> 4년 연속 베스트셀러 1위! ★★★★\n《DO IT! 점프 투 <b>파이썬</b>》 전면 개정판 출시!\n문과생도 중고등학생도 직장인도 프로그래밍에 눈뜨게 만든... 점프 투 <b>파이썬</b>》으로 출간되었던 이 책은 약 4년 동안의 피드백을 반영하여 초보자가 더 빠르게 입문하고, 더 깊이 있게 공부할 수 있도록 개정되었다.... "
#
# },
# {
# "title": "머신 러닝 교과서 with <b>파이썬</b>, 사이킷런, 텐서플로",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14922892",
# "image": "https://bookthumb-phinf.pstatic.net/cover/149/228/14922892.jpg?type=m1&udate=20191011",
# "author": "세바스찬 라시카|바히드 미자리리",
# "price": "33000",
# "discount": "29700",
# "publisher": "길벗",
# "pubdate": "20190524",
# "isbn": "1160507961 9791160507966",
# "description": "<b>파이썬</b> 언어와 <b>파이썬</b> 기반의 머신 러닝 핵심 라이브러리(SciPy, NumPy, scikit-learn, Matplotlib, Pandas)를 사용해 머신 러닝을, 텐서플로를 사용해 딥러닝을 실습하면서 머신 러닝과 딥러닝 핵심 알고리즘을 설명하고, 간단한 알고리즘은 처음부터 직접 구현해본다. 또한, 사이킷런의 기여자이자 mlxtend... "
#
# },
# {
# "title": "모두의 데이터 분석 with <b>파이썬</b> (실생활 예제로 시작하는 데이터 분석 첫걸음)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14820571",
# "image": "https://bookthumb-phinf.pstatic.net/cover/148/205/14820571.jpg?type=m1&udate=20191011",
# "author": "송석리|이현아",
# "price": "18000",
# "discount": "16200",
# "publisher": "길벗",
# "pubdate": "20190425",
# "isbn": "1160507813 9791160507812",
# "description": "데이터 다운로드부터 정제, 문제 해결 방법 구상, <b>파이썬</b> 코드로 구현까지 차근차근 진행하면서, 초보자가 데이터 분석의 성공적인 첫걸음을 내딛도록... 최소한의 <b>파이썬</b> 문법만을 사용하여 설명하므로 프로그래밍 경험이 적은 사람도 충분히 따라 할 수 있다. 이제 데이터 분석 전문가가 아니어도, 자신의... "
#
# },
# {
# "title": "<b>파이썬</b> 라이브러리를 활용한 데이터 분석 (영화 평점, 이름 통계, 선거 데이터 등 실사례 사용)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14922211",
# "image": "https://bookthumb-phinf.pstatic.net/cover/149/222/14922211.jpg?type=m1&udate=20191011",
# "author": "웨스 맥키니",
# "price": "35000",
# "discount": "31500",
# "publisher": "한빛미디어",
# "pubdate": "20190520",
# "isbn": "116224190X 9791162241905",
# "description": "&#x0D;&#x0D;이 책은 NumPy, pandas, matplotlib, IPython, Jupyter 등 다양한 <b>파이썬</b> 라이브러리를 사용해서 효과적으로 데이터를 분석하는 방법을 알려준다. pandas의 새로운 기능뿐만 아니라 메모리 사용량을 줄이고 성능을 개선하는 고급 사용법까지 다룬다. 또한 모델링 도구인 statsmodels와 scikit-learn... "
#
# },
# {
# "title": "<b>파이썬</b> 라이브러리를 활용한 머신러닝 (번역개정판,사이킷런 핵심 개발자가 쓴 머신러닝과 데이터 과학 실무서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14645299",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/452/14645299.jpg?type=m1&udate=20191122",
# "author": "안드레아스 뮐러|세라 가이도",
# "price": "32000",
# "discount": "28800",
# "publisher": "한빛미디어",
# "pubdate": "20190329",
# "isbn": "1162241640 9791162241646",
# "description": "사이킷런 핵심 개발자에게 배우는 머신러닝 이론과 구현\n\n현업에서 머신러닝을 연구하고 인공지능 서비스를 개발하기 위해 꼭 학위를 받을 필요는 없습니다. 사이킷런(SCIKIT-LEARN)과 같은 훌륭한 머신러닝 라이브러리가 복잡하고 난해한 작업을 직관적인 인터페이스로 감싸주는 덕분이죠. 이 책에서는... "
#
# },
# {
# "title": "<b>파이썬</b> 머신러닝 완벽 가이드 (다양한 캐글 예제와 함께 기초 알고리즘부터 최신 기법까지 배우는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14568657",
# "image": "https://bookthumb-phinf.pstatic.net/cover/145/686/14568657.jpg?type=m1&udate=20191010",
# "author": "권철민",
# "price": "38000",
# "discount": "34200",
# "publisher": "위키북스",
# "pubdate": "20190228",
# "isbn": "1158391382 9791158391386",
# "description": "자세한 이론 설명과 <b>파이썬</b> 실습을 통해 머신러닝을 완벽하게 배울 수 있습니다!\n\n《<b>파이썬</b> 머신러닝 완벽 가이드》는 이론 위주의 머신러닝 책에서 탈피해 다양한 실전 예제를 직접 구현해 보면서 머신러닝을 체득할 수 있도록 만들었습니다.  캐글과 UCI 머신러닝 리포지토리에서 난이도가 있는 실습... "
#
# }
# ]
# }

# %%
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/movie?query=" + encText
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)

response = urllib.request.urlopen(request)
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Fri, 22 Nov 2019 20:57:59 +0900",
# "total": 1,
# "start": 1,
# "display": 1,
# "items": [
# {
# "title": "<b>파이썬</b> 앤 가드",
# "link": "https://movie.naver.com/movie/bi/mi/basic.nhn?code=152070",
# "image": "https://ssl.pstatic.net/imgmovie/mdi/mit110/1520/152070_P01_145336.jpg",
# "subtitle": "PYTHON AND GUARD",
# "pubDate": "2015",
# "director": "안톤 디아코프|",
# "actor": "",
# "userRating": "0.00"
#
# }
# ]
# }

# %%
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)

response = urllib.request.urlopen(request)
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Fri, 22 Nov 2019 20:57:59 +0900",
# "total": 70708,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "대구<b>파이썬</b>전문교육 :: <b>파이썬</b> 배우고 전공대비 / 취업 준비 제대로 하자!",
# "link": "http://cafe.naver.com/power119/681609",
# "description": "안녕하세요 ~ KG아이티뱅크에서 IT 교육 / 진로 / 취업 상담 등을 도와드리고 있는 IT교육컨설턴트 윤쌤이에요~ 오늘 소개해드릴 내용은 학교에서 배웠던 <b>파이썬</b> 내용이 부족하신 분들을 위해 프로그래밍의 시작인 <b>파이썬</b>... ",
# "cafename": "전기박사",
# "cafeurl": "https://cafe.naver.com/power119"
#
# },
# {
# "title": "강남<b>파이썬</b>전문교육 :: <b>파이썬</b>의 기초부터 실습을 통한 심화과정까지 체계적으로!",
# "link": "http://cafe.naver.com/specup/6140082",
# "description": "내용은 <b>파이썬</b> 프로그래밍을 처음 배우시는 초보자 / 비전공자분들을 위해 프로그래밍의 시작인 <b>파이썬</b> 기초부터 심화과정까지 체계적인 실습위주로 진행되고 있는 강남<b>파이썬</b>전문교육 에 대해 자세히 알려드리도록... ",
# "cafename": "스펙업 | 대학생,대외활동,공모전,알바...",
# "cafeurl": "https://cafe.naver.com/specup"
#
# },
# {
# "title": "서울<b>파이썬</b>전문학원 :: <b>파이썬</b> 프로그래밍 제대로 배울 수 있는 전문학원!",
# "link": "http://cafe.naver.com/foodbbo/108692",
# "description": "내용은 <b>파이썬</b> 프로그래밍을 처음 배우시는 초보자 / 비전공자분들을 위해 프로그래밍의 시작인 <b>파이썬</b> 기초부터 심화과정까지 체계적으로 진행되고 있는 서울<b>파이썬</b>전문학원 에 대해 자세히 알려드리도록 하겠습니다... ",
# "cafename": "식품(산업)기사 뽀개기",
# "cafeurl": "https://cafe.naver.com/foodbbo"
#
# },
# {
# "title": "종로<b>파이썬</b>기초교육 :: <b>파이썬</b> 기초부터 심화까지 제대로 배울수 있는 교육기관!",
# "link": "http://cafe.naver.com/publiccor/176072",
# "description": "내용은 <b>파이썬</b> 프로그래밍을 처음 배우시는 초보자 / 비전공자분들을 위해 프로그래밍의 시작인 <b>파이썬</b> 기초부터 심화과정까지 체계적으로 진행되고 있는 종로<b>파이썬</b>기초교육 에 대해 자세히 알려드리도록 하겠습니다... ",
# "cafename": "국민건강보험공단 건강보험심사평가원...",
# "cafeurl": "https://cafe.naver.com/publiccor"
#
# },
# {
# "title": "노량진<b>파이썬</b>전문학원 :: 프로그래밍의 시작점, <b>파이썬</b>을 쉽게 배울 수 있는 교육학원!",
# "link": "http://cafe.naver.com/goondae/2180992",
# "description": "내용은 <b>파이썬</b> 프로그래밍을 처음 배우시는 초보자 / 비전공자분들을 위해 프로그래밍의 시작인 <b>파이썬</b> 기초부터 심화과정까지 체계적으로 진행되고 있는 노량진<b>파이썬</b>전문학원 에 대해 자세히 알려드리도록... ",
# "cafename": "전대모 (대학생,레포트,토익,족보,스펙...",
# "cafeurl": "https://cafe.naver.com/goondae"
#
# },
# {
# "title": "부산<b>파이썬</b>전문학원 :: <b>파이썬</b> 프로그래밍 관심있는 분들 여기 주목해주세요!",
# "link": "http://cafe.naver.com/chokingwang/44927",
# "description": "내용은 <b>파이썬</b> 프로그래밍을 처음 배우시는 초보자 / 비전공자분들을 위해 프로그래밍의 시작인 <b>파이썬</b> 기초부터 심화과정까지 체계적으로 진행되고 있는 부산<b>파이썬</b>전문학원 에 대해 자세히 알려드리도록 하겠습니다... ",
# "cafename": "교육공무직원. 교육실무직원 소양평가...",
# "cafeurl": "https://cafe.naver.com/chokingwang"
#
# },
# {
# "title": "대구<b>파이썬</b>기초교육 :: <b>파이썬</b>교육부터 취업까지 완벽히 갖춰진 학원!",
# "link": "http://cafe.naver.com/power119/680950",
# "description": "내용은 <b>파이썬</b> 프로그래밍을 처음 배우시는 초보자 / 비전공자분들을 위해 프로그래밍의 시작인 <b>파이썬</b> 기초부터 심화과정까지 더 나아가 취업까지 완벽하게 체계적으로 진행되고 있는 대구<b>파이썬</b>기초교육 에 대해... ",
# "cafename": "전기박사",
# "cafeurl": "https://cafe.naver.com/power119"
#
# },
# {
# "title": "서울<b>파이썬</b>전문교육 :: <b>파이썬</b>교육, 기초부터 한 걸음씩 더 깊고 자세하게!",
# "link": "http://cafe.naver.com/foodbbo/108693",
# "description": "시작인 <b>파이썬</b> 기초부터 심화과정까지 한 걸음 더 깊고 자세하게 수업이 진행되는 서울<b>파이썬</b>전문교육 에 대해 자세히 알려드리도록 하겠습니다 <b>파이썬</b> 은 높은 생산성을 가지고 있는 프로그래밍 언어로 C언어나 JAVA... ",
# "cafename": "식품(산업)기사 뽀개기",
# "cafeurl": "https://cafe.naver.com/foodbbo"
#
# },
# {
# "title": "서울<b>파이썬</b>기초교육 :: <b>파이썬</b>교육 제대로 배우고 취업까지 한번에 가자!!",
# "link": "http://cafe.naver.com/foodbbo/108649",
# "description": "내용은 <b>파이썬</b> 프로그래밍을 처음 배우시는 초보자 / 비전공자분들을 위해 프로그래밍의 시작인 <b>파이썬</b> 기초부터 심화과정까지 더 나아가 취업까지 완벽하게 체계적으로 진행되고 있는 서울<b>파이썬</b>기초교육 에 대해... ",
# "cafename": "식품(산업)기사 뽀개기",
# "cafeurl": "https://cafe.naver.com/foodbbo"
#
# },
# {
# "title": "노량진<b>파이썬</b>전문교육 :: 프로그래밍의 시작점 <b>파이썬</b>을 기초부터 완벽하게 진행하는 곳!",
# "link": "http://cafe.naver.com/goondae/2181419",
# "description": "시작인 <b>파이썬</b> 기초부터 심화과정까지 체계적인 진행되고 있는 노량진<b>파이썬</b>전문교육 에 대해 자세히 알려드리도록 하겠습니다 <b>파이썬</b> 은 높은 생산성을 가지고 있는 프로그래밍 언어로 C언어나 JAVA 같은 언어에... ",
# "cafename": "전대모 (대학생,레포트,토익,족보,스펙...",
# "cafeurl": "https://cafe.naver.com/goondae"
#
# }
# ]
# }

# %%
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)

response = urllib.request.urlopen(request)
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Fri, 22 Nov 2019 20:58:00 +0900",
# "total": 141399,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "나이키 에어맥스 97 플래티넘 <b>파이톤</b> 921733-017",
# "link": "https://search.shopping.naver.com/gate.nhn?id=20870714142",
# "image": "https://shopping-phinf.pstatic.net/main_2087071/20870714142.20190913130439.jpg",
# "lprice": "150000",
# "hprice": "283800",
# "mallName": "네이버",
# "productId": "20870714142",
# "productType": "1"
#
# },
# {
# "title": "별 <b>파이톤</b> 드레이핑 셔링원피스",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21042366001",
# "image": "https://shopping-phinf.pstatic.net/main_2104236/21042366001.20191008162905.jpg",
# "lprice": "32166",
# "hprice": "35640",
# "mallName": "네이버",
# "productId": "21042366001",
# "productType": "1"
#
# },
# {
# "title": "<b>파이톤</b> 레자치마바지",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21094811398",
# "image": "https://shopping-phinf.pstatic.net/main_2109481/21094811398.20191017014428.jpg",
# "lprice": "18900",
# "hprice": "18900",
# "mallName": "네이버",
# "productId": "21094811398",
# "productType": "1"
#
# },
# {
# "title": "잘모이 ZARMOI 미뇽 <b>파이톤</b> 핸드백 수원",
# "link": "https://search.shopping.naver.com/gate.nhn?id=15158459821",
# "image": "https://shopping-phinf.pstatic.net/main_1515845/15158459821.20190519043644.jpg",
# "lprice": "79110",
# "hprice": "2030580",
# "mallName": "네이버",
# "productId": "15158459821",
# "productType": "1"
#
# },
# {
# "title": "잘모이 ZARMOI 하모니 <b>파이톤</b> 도트백 수원",
# "link": "https://search.shopping.naver.com/gate.nhn?id=14422438506",
# "image": "https://shopping-phinf.pstatic.net/main_1442243/14422438506.20190921005644.jpg",
# "lprice": "79110",
# "hprice": "398700",
# "mallName": "네이버",
# "productId": "14422438506",
# "productType": "1"
#
# },
# {
# "title": "잘모이 Limited Edition 리얼 <b>파이톤</b> 시티 빅 토트 아이웨어 레더 케이스",
# "link": "https://search.shopping.naver.com/gate.nhn?id=20725638889",
# "image": "https://shopping-phinf.pstatic.net/main_2072563/20725638889.20190823154149.jpg",
# "lprice": "350610",
# "hprice": "376200",
# "mallName": "네이버",
# "productId": "20725638889",
# "productType": "1"
#
# },
# {
# "title": "보스 <b>파이톤</b> 쉬폰원피스 2col",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21068077486",
# "image": "https://shopping-phinf.pstatic.net/main_2106807/21068077486.20191012160116.jpg",
# "lprice": "29900",
# "hprice": "29900",
# "mallName": "네이버",
# "productId": "21068077486",
# "productType": "1"
#
# },
# {
# "title": "<b>파이톤</b> 뱀피 첼시 부츠",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21062294526",
# "image": "https://shopping-phinf.pstatic.net/main_2106229/21062294526.20191011161534.jpg",
# "lprice": "40000",
# "hprice": "40000",
# "mallName": "네이버",
# "productId": "21062294526",
# "productType": "1"
#
# },
# {
# "title": "국내제작 고급 천연소가죽 <b>파이톤</b> 배색 기모안감 통굽 가보시힐 앵글부츠 6cm",
# "link": "https://search.shopping.naver.com/gate.nhn?id=12861898618",
# "image": "https://shopping-phinf.pstatic.net/main_1286189/12861898618.3.jpg",
# "lprice": "54900",
# "hprice": "0",
# "mallName": "라온디",
# "productId": "12861898618",
# "productType": "2"
#
# },
# {
# "title": "잘모이 뉴블 미뇽 <b>파이톤</b> 토트숄더백 Z318FHT104PM",
# "link": "https://search.shopping.naver.com/gate.nhn?id=16613771769",
# "image": "https://shopping-phinf.pstatic.net/main_1661377/16613771769.20181214181409.jpg",
# "lprice": "104470",
# "hprice": "158000",
# "mallName": "네이버",
# "productId": "16613771769",
# "productType": "1"
#
# }
# ]
# }

# %%
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/encyc?query=" + encText
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)

response = urllib.request.urlopen(request)
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Fri, 22 Nov 2019 20:58:01 +0900",
# "total": 396,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b>",
# "link": "https://terms.naver.com/entry.nhn?docId=3580815&cid=59088&categoryId=59096",
# "description": "‘<b>파이썬</b>’이다. 간결한 문법으로 입문자가 이해하기 쉽고, 다양한 분야에 활용할 수 있기 때문이다. 이 외에도 <b>파이썬</b>은 머신러닝, 그래픽, 웹 개발 등 여러 업계에서 선호하는 언어로 꾸준히... ",
# "thumbnail": "http://openapi-dbscthumb.phinf.naver.net/4749_000_1/20170118193349632_0CHSSS5Y6.png/01_16.png?type=m160_160"
#
# },
# {
# "title": "<b>파이썬</b>",
# "link": "https://terms.naver.com/entry.nhn?docId=3607513&cid=58598&categoryId=59316",
# "description": " 컴퓨터 언어의 일종으로 간결하고 생산성 높은 프로그래밍 언어.  <b>파이썬</b>(python)은 프로그램을 설계하는 프로그래밍 언어 중 하나입니다. 컴퓨터는 0과 1을(이진수) 인식하여 작동하기 때문에 과거에는... ",
# "thumbnail": "http://openapi-dbscthumb.phinf.naver.net/4751_000_3/20170710213206672_OPHLG2VOW.jpg/992_170575_10034.jpg?type=m160_160"
#
# },
# {
# "title": "<b>파이썬</b>",
# "link": "https://terms.naver.com/entry.nhn?docId=3533295&cid=40942&categoryId=32838",
# "description": " 오픈소스 고급 프로그래밍 언어 중 하나이다.  C언어를 기반으로 한 오픈소스 고급 프로그래밍 언어로, 1991년 귀도 반 로섬(Guido van Rossum)에 의해 설계 및 개발되었다. <b>파이썬</b>이라는 이름은 <b>파이썬</b>을... ",
# "thumbnail": ""
#
# },
# {
# "title": "<b>파이썬</b>",
# "link": "https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC",
# "description": "<b>파이썬</b> ( 영어: Python )은 1991년 프로그래머인 귀도 반 로섬(Guido van Rossum)이 발표한 고급 프로그래밍 언어로, 플랫폼 독립적이며 인터프리터식, 객체지향적, 동적 타이핑(dynamically typed) 대화형... ",
# "thumbnail": ""
#
# },
# {
# "title": "바이오<b>파이썬</b>",
# "link": "https://ko.wikipedia.org/wiki/%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%8C%EC%9D%B4%EC%8D%AC",
# "description": "바이오<b>파이썬</b> (Biopython) 프로젝트는 분자생물학 계산에 자유롭게 사용하기 위한 <b>파이썬</b> 라이브러리 구축 프로젝트이다. 같이 보기 바이오자바 바이오펄 외부 링크 biopython.org",
# "thumbnail": ""
#
# },
# {
# "title": "<b>파이썬</b>의 역사",
# "link": "https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%9D%98_%EC%97%AD%EC%82%AC",
# "description": "프로그래밍 언어 <b>파이썬</b>은 1980년대 말에 구상되었으며 그 구현체는 1989년 12월 예외 처리가 가능하고 아메바 운영 체제와 통신이 가능한 ABC의 후속 프로그래밍 언어로서 CWI(Centrum... ",
# "thumbnail": ""
#
# },
# {
# "title": "아나콘다 (<b>파이썬</b> 배포판)",
# "link": "https://ko.wikipedia.org/wiki/%EC%95%84%EB%82%98%EC%BD%98%EB%8B%A4_(%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%B0%B0%ED%8F%AC%ED%8C%90)",
# "description": "아나콘다 (Anaconda)는 패키지 관리와 디플로이를 단순케 할 목적으로 과학 계산(데이터 과학, 기계 학습 애플리케이션, 대규모 데이터 처리, 예측 분석 등)을 위해 <b>파이썬</b>과 R 프로그래밍 언어의 자유... ",
# "thumbnail": ""
#
# },
# {
# "title": "<b>파이썬</b> 소프트웨어 재단",
# "link": "https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%86%8C%ED%94%84%ED%8A%B8%EC%9B%A8%EC%96%B4_%EC%9E%AC%EB%8B%A8",
# "description": "<b>파이썬</b> 소프트웨어 재단 (Python Software Foundation, PSF)은 <b>파이썬</b> 프로그래밍 언어에 헌신하는 비영리 단체로서, 2001년 3월 6일 런칭했다. 이 단체의 임무는 <b>파이썬</b> 공동체의 개발을 발전시키고... ",
# "thumbnail": ""
#
# },
# {
# "title": "자이썬",
# "link": "https://ko.wikipedia.org/wiki/%EC%9E%90%EC%9D%B4%EC%8D%AC",
# "description": "자이썬 ( Jython )은 <b>파이썬</b>의 자바 구현으로, Jim Hugunin에 의해 처음으로 만들어졌다. 처음에는 <b>파이썬</b> 표준 구현의 이름(CPython)을 따라 JPython 라는 이름을 썼다. 자이썬은 자바 언어로만 작성되었기... ",
# "thumbnail": ""
#
# },
# {
# "title": "Pip (패키지 관리자)",
# "link": "https://ko.wikipedia.org/wiki/Pip_(%ED%8C%A8%ED%82%A4%EC%A7%80_%EA%B4%80%EB%A6%AC%EC%9E%90)",
# "description": "pip 는 <b>파이썬</b>으로 작성된 패키지 소프트웨어를 설치 · 관리하는 패키지 관리 시스템이다. Python Package Index (PyPI)에서 많은 <b>파이썬</b> 패키지를 볼 수 있다. <b>파이썬</b> 2.7.9 이후 버전과 <b>파이썬</b> 3.4 이후... ",
# "thumbnail": ""
#
# }
# ]
# }

# %%
encText = urllib.parse.quote("몰스킨")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)

response = urllib.request.urlopen(request)
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Fri, 22 Nov 2019 20:58:01 +0900",
# "total": 33724,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "[스벅 균일가] 2020 스타벅스 다이어리 / 라미 볼 펜 세트 / 카카오프렌즈",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82256791829",
# "image": "https://shopping-phinf.pstatic.net/main_8225679/82256791829.2.jpg",
# "lprice": "20000",
# "hprice": "0",
# "mallName": "도담도담 샵",
# "productId": "82256791829",
# "productType": "2"
#
# },
# {
# "title": "[스타벅스 균일가] 2020 스타벅스 다이어리 / 라미 볼 펜 세트,<b>몰스킨</b>, 카카오프렌즈",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82257291445",
# "image": "https://shopping-phinf.pstatic.net/main_8225729/82257291445.jpg",
# "lprice": "19000",
# "hprice": "0",
# "mallName": "별콩샵",
# "productId": "82257291445",
# "productType": "2"
#
# },
# {
# "title": "2020 스타벅스 다이어리 <b>몰스킨</b> 플래너 그린 라이트블루 퍼플 핑크 라미 볼 펜 세트",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82257434708",
# "image": "https://shopping-phinf.pstatic.net/main_8225743/82257434708.jpg",
# "lprice": "32500",
# "hprice": "0",
# "mallName": "우멍가게",
# "productId": "82257434708",
# "productType": "2"
#
# },
# {
# "title": "[<b>몰스킨</b>]무료각인/포장 [소프트] 2020 위클리 블랙-포켓",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21032238429",
# "image": "https://shopping-phinf.pstatic.net/main_2103223/21032238429.jpg",
# "lprice": "21320",
# "hprice": "0",
# "mallName": "롯데닷컴",
# "productId": "21032238429",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 클래식 룰드 줄지",
# "link": "https://search.shopping.naver.com/gate.nhn?id=7398991731",
# "image": "https://shopping-phinf.pstatic.net/main_7398991/7398991731.20180112135400.jpg",
# "lprice": "17500",
# "hprice": "36300",
# "mallName": "네이버",
# "productId": "7398991731",
# "productType": "1"
#
# },
# {
# "title": "<b>몰스킨</b> 2020 데일리 12개월 다이어리 하드커버 라지",
# "link": "https://search.shopping.naver.com/gate.nhn?id=20967832214",
# "image": "https://shopping-phinf.pstatic.net/main_2096783/20967832214.20190927153428.jpg",
# "lprice": "38500",
# "hprice": "38500",
# "mallName": "네이버",
# "productId": "20967832214",
# "productType": "1"
#
# },
# {
# "title": "<b>몰스킨</b> 2020 데일리 다이어리 어린왕자",
# "link": "https://search.shopping.naver.com/gate.nhn?id=20889110828",
# "image": "https://shopping-phinf.pstatic.net/main_2088911/20889110828.20190917103300.jpg",
# "lprice": "35200",
# "hprice": "35800",
# "mallName": "네이버",
# "productId": "20889110828",
# "productType": "1"
#
# },
# {
# "title": "<b>몰스킨</b> 2020 위클리 플래너 라지 하드커버 <b>Moleskine</b>",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21155563019",
# "image": "https://shopping-phinf.pstatic.net/main_2115556/21155563019.jpg",
# "lprice": "26900",
# "hprice": "0",
# "mallName": "까만돌코리아",
# "productId": "21155563019",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 스타벅스 2019 다이어리 플래너",
# "link": "https://search.shopping.naver.com/gate.nhn?id=17127390818",
# "image": "https://shopping-phinf.pstatic.net/main_1712739/17127390818.20190121155103.jpg",
# "lprice": "19900",
# "hprice": "29000",
# "mallName": "네이버",
# "productId": "17127390818",
# "productType": "1"
#
# },
# {
# "title": "<b>몰스킨</b> 클래식 플레인 하드커버 노트 라지 240매  블랙  1개",
# "link": "https://search.shopping.naver.com/gate.nhn?id=20268605825",
# "image": "https://shopping-phinf.pstatic.net/main_2026860/20268605825.jpg",
# "lprice": "22150",
# "hprice": "0",
# "mallName": "쿠팡",
# "productId": "20268605825",
# "productType": "2"
#
# }
# ]
# }

# %%
def gen_search_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)

    return base + node + param_query + param_start + param_disp

# %%
gen_search_url('shop', 'TEST', 10, 3)
# Out:
# 'https://openapi.naver.com/v1/search/shop.json?query=TEST&start=10&display=3'

# %%
import json
import datetime

def get_result_onpage(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    
    response = urllib.request.urlopen(request)
    
    print ("[%s] Url Request Success" % datetime.datetime.now())
    
    return json.loads(response.read().decode('utf-8'))

# %%
client_id = '---'
client_secret = "---"

url = gen_search_url('shop', '몰스킨', 1, 5)
one_result = get_result_onpage(url)
# Out:
# [2019-11-22 20:58:03.327826] Url Request Success

# %%
one_result
# Out:
# {'lastBuildDate': 'Fri, 22 Nov 2019 20:58:03 +0900',
#  'total': 33724,
#  'start': 1,
#  'display': 5,
#  'items': [{'title': '[스벅 균일가] 2020 스타벅스 다이어리 / 라미 볼 펜 세트 / 카카오프렌즈',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=82256791829',
#    'image': 'https://shopping-phinf.pstatic.net/main_8225679/82256791829.2.jpg',
#    'lprice': '20000',
#    'hprice': '0',
#    'mallName': '도담도담 샵',
#    'productId': '82256791829',
#    'productType': '2'},
#   {'title': '[스타벅스 균일가] 2020 스타벅스 다이어리 / 라미 볼 펜 세트,<b>몰스킨</b>, 카카오프렌즈',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=82257291445',
#    'image': 'https://shopping-phinf.pstatic.net/main_8225729/82257291445.jpg',
#    'lprice': '19000',
#    'hprice': '0',
#    'mallName': '별콩샵',
#    'productId': '82257291445',
#    'productType': '2'},
#   {'title': '2020 스타벅스 다이어리 <b>몰스킨</b> 플래너 그린 라이트블루 퍼플 핑크 라미 볼 펜 세트',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=82257434708',
#    'image': 'https://shopping-phinf.pstatic.net/main_8225743/82257434708.jpg',
#    'lprice': '32500',
#    'hprice': '0',
#    'mallName': '우멍가게',
#    'productId': '82257434708',
#    'productType': '2'},
#   {'title': '[<b>몰스킨</b>]무료각인/포장 [소프트] 2020 위클리 블랙-포켓',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=21032238429',
#    'image': 'https://shopping-phinf.pstatic.net/main_2103223/21032238429.jpg',
#    'lprice': '21320',
#    'hprice': '0',
#    'mallName': '롯데닷컴',
#    'productId': '21032238429',
#    'productType': '2'},
#   {'title': '<b>몰스킨</b> 클래식 룰드 줄지',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=7398991731',
#    'image': 'https://shopping-phinf.pstatic.net/main_7398991/7398991731.20180112135400.jpg',
#    'lprice': '17500',
#    'hprice': '36300',
#    'mallName': '네이버',
#    'productId': '7398991731',
#    'productType': '1'}]}

# %%
one_result['items'][0]['title']
# Out:
# '[스벅 균일가] 2020 스타벅스 다이어리 / 라미 볼 펜 세트 / 카카오프렌즈'

# %%
one_result['items'][0]['lprice']
# Out:
# '20000'

# %%
one_result['items'][0]['mallName']
# Out:
# '도담도담 샵'

# %%
import pandas as pd

def get_fields(json_data):
    title = [each['title'] for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    lprice = [each['lprice'] for each in json_data['items']]
    hprice = [each['hprice'] for each in json_data['items']]
    mall_name = [each['mallName'] for each in json_data['items']]

    result_pd = pd.DataFrame({'title':title, 'lprice':lprice, 
                              'hprice':hprice, 'link':link,
                              'mall':mall_name}, 
                             columns=['title','lprice','hprice','link', 'mall'])
    
    return result_pd

# %%
get_fields(one_result)
# Out:
#                                                title lprice hprice  \
# 0       [스벅 균일가] 2020 스타벅스 다이어리 / 라미 볼 펜 세트 / 카카오프렌즈  20000      0
# 1  [스타벅스 균일가] 2020 스타벅스 다이어리 / 라미 볼 펜 세트,<b>몰스킨</...  19000      0
# 2  2020 스타벅스 다이어리 <b>몰스킨</b> 플래너 그린 라이트블루 퍼플 핑크 라...  32500      0
# 3           [<b>몰스킨</b>]무료각인/포장 [소프트] 2020 위클리 블랙-포켓  21320      0
# 4                               <b>몰스킨</b> 클래식 룰드 줄지  17500  36300
#
#                                                 link    mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  도담도담 샵
# 1  https://search.shopping.naver.com/gate.nhn?id=...     별콩샵
# 2  https://search.shopping.naver.com/gate.nhn?id=...    우멍가게
# 3  https://search.shopping.naver.com/gate.nhn?id=...    롯데닷컴
# 4  https://search.shopping.naver.com/gate.nhn?id=...     네이버

# %%
def delete_tag(input_str):
    input_str = input_str.replace("<b>", "")
    input_str = input_str.replace("</b>", "")
    
    return input_str

# %%
def get_fields(json_data):
    title = [delete_tag(each['title']) for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    lprice = [each['lprice'] for each in json_data['items']]
    hprice = [each['hprice'] for each in json_data['items']]
    mall_name = [each['mallName'] for each in json_data['items']]

    result_pd = pd.DataFrame({'title':title, 'lprice':lprice, 
                              'hprice':hprice, 'link':link,
                              'mall':mall_name}, 
                             columns=['title','lprice','hprice','link', 'mall'])
    
    return result_pd

# %%
url = gen_search_url('shop', '몰스킨', 1, 5)
json_result = get_result_onpage(url)
pd_result = get_fields(json_result)
# Out:
# [2019-11-22 20:58:07.085412] Url Request Success

# %%
pd_result
# Out:
#                                                title lprice hprice  \
# 0       [스벅 균일가] 2020 스타벅스 다이어리 / 라미 볼 펜 세트 / 카카오프렌즈  20000      0
# 1  [스타벅스 균일가] 2020 스타벅스 다이어리 / 라미 볼 펜 세트,몰스킨, 카카오프렌즈  19000      0
# 2    2020 스타벅스 다이어리 몰스킨 플래너 그린 라이트블루 퍼플 핑크 라미 볼 펜 세트  32500      0
# 3                  [몰스킨]무료각인/포장 [소프트] 2020 위클리 블랙-포켓  21320      0
# 4                                      몰스킨 클래식 룰드 줄지  17500  36300
#
#                                                 link    mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  도담도담 샵
# 1  https://search.shopping.naver.com/gate.nhn?id=...     별콩샵
# 2  https://search.shopping.naver.com/gate.nhn?id=...    우멍가게
# 3  https://search.shopping.naver.com/gate.nhn?id=...    롯데닷컴
# 4  https://search.shopping.naver.com/gate.nhn?id=...     네이버

# %%
for n in range(1,1000,100):
    print(n)
# Out:
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901

# %%
result_mol = []

for n in range(1,1000,100):
    url = gen_search_url('shop', '몰스킨', n, 100)
    json_result = get_result_onpage(url)
    pd_result = get_fields(json_result)
    
    result_mol.append(pd_result)

result_mol = pd.concat(result_mol)
# Out:
# [2019-11-22 20:58:08.451637] Url Request Success
# [2019-11-22 20:58:08.709339] Url Request Success
# [2019-11-22 20:58:08.958883] Url Request Success
# [2019-11-22 20:58:09.214327] Url Request Success
# [2019-11-22 20:58:09.483475] Url Request Success
# [2019-11-22 20:58:09.757218] Url Request Success
# [2019-11-22 20:58:10.019535] Url Request Success
# [2019-11-22 20:58:10.277187] Url Request Success
# [2019-11-22 20:58:10.520760] Url Request Success
# [2019-11-22 20:58:10.767334] Url Request Success

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 99
# Data columns (total 5 columns):
# title     1000 non-null object
# lprice    1000 non-null object
# hprice    1000 non-null object
# link      1000 non-null object
# mall      1000 non-null object
# dtypes: object(5)
# memory usage: 46.9+ KB

# %%
result_mol.reset_index(drop=True, inplace=True)

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
# title     1000 non-null object
# lprice    1000 non-null object
# hprice    1000 non-null object
# link      1000 non-null object
# mall      1000 non-null object
# dtypes: object(5)
# memory usage: 39.2+ KB

# %%
result_mol.head()
# Out:
#                                                title lprice hprice  \
# 0       [스벅 균일가] 2020 스타벅스 다이어리 / 라미 볼 펜 세트 / 카카오프렌즈  20000      0
# 1  [스타벅스 균일가] 2020 스타벅스 다이어리 / 라미 볼 펜 세트,몰스킨, 카카오프렌즈  19000      0
# 2    2020 스타벅스 다이어리 몰스킨 플래너 그린 라이트블루 퍼플 핑크 라미 볼 펜 세트  32500      0
# 3                  [몰스킨]무료각인/포장 [소프트] 2020 위클리 블랙-포켓  21320      0
# 4                                      몰스킨 클래식 룰드 줄지  17500  36300
#
#                                                 link    mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  도담도담 샵
# 1  https://search.shopping.naver.com/gate.nhn?id=...     별콩샵
# 2  https://search.shopping.naver.com/gate.nhn?id=...    우멍가게
# 3  https://search.shopping.naver.com/gate.nhn?id=...    롯데닷컴
# 4  https://search.shopping.naver.com/gate.nhn?id=...     네이버

# %%
result_mol['lprice'] = result_mol['lprice'].astype('float')
result_mol['hprice'] = result_mol['hprice'].astype('float')
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
# title     1000 non-null object
# lprice    1000 non-null float64
# hprice    1000 non-null float64
# link      1000 non-null object
# mall      1000 non-null object
# dtypes: float64(2), object(3)
# memory usage: 39.2+ KB

# %%
writer = pd.ExcelWriter("./data/06_molskin_diary_in_naver_shop.xlsx", 
                        engine='xlsxwriter')
result_mol.to_excel(writer, sheet_name='Sheet1')

workbook  = writer.book
worksheet = writer.sheets['Sheet1']
worksheet.set_column('A:A', 4)
worksheet.set_column('B:B', 60)
worksheet.set_column('C:C', 10)
worksheet.set_column('D:D', 10)
worksheet.set_column('E:E', 50)
worksheet.set_column('F:F', 10)

worksheet.conditional_format('C2:C1001', {'type': '3_color_scale'})

writer.save()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-a7615b4f5d68> in <module>
#       1 writer = pd.ExcelWriter("./data/06_molskin_diary_in_naver_shop.xlsx",
# ----> 2                         engine='xlsxwriter')
#       3 result_mol.to_excel(writer, sheet_name='Sheet1')
#       4
#       5 workbook  = writer.book
#
# /anaconda3/envs/new_env/lib/python3.7/site-packages/pandas/io/excel/_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, **engine_kwargs)
#     172     ):
#     173         # Use the xlsxwriter module as the Excel writer.
# --> 174         import xlsxwriter
#     175
#     176         if mode == "a":
#
# ModuleNotFoundError: No module named 'xlsxwriter'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

f_path = "/Library/Fonts/AppleGothic.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
plt.figure(figsize=(15,6))
sns.countplot('mall', data=result_mol, palette='RdYlGn',
              order=result_mol['mall'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ---

# %%
body = {
    "startDate":"2017-01-01",
    "endDate":"2017-04-30",
    "timeUnit":"month",
    "keywordGroups":[
        {"groupName":"한글","keywords":["한글","korean"]},
        {"groupName":"영어","keywords":["영어","english"]},
    ],
    "device":"pc",
    "ages":["1","2"],
    "gender":"f"
}

# %%
import json

body = json.dumps(body, indent=4, ensure_ascii=False)
print(body)
# Out:
# {
#     "startDate": "2017-01-01",
#     "endDate": "2017-04-30",
#     "timeUnit": "month",
#     "keywordGroups": [
#         {
#             "groupName": "한글",
#             "keywords": [
#                 "한글",
#                 "korean"
#             ]
#         },
#         {
#             "groupName": "영어",
#             "keywords": [
#                 "영어",
#                 "english"
#             ]
#         }
#     ],
#     "device": "pc",
#     "ages": [
#         "1",
#         "2"
#     ],
#     "gender": "f"
# }

# %%
url = "https://openapi.naver.com/v1/datalab/search"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))

json.loads(response.read().decode('utf-8'))
# Out:
# {'startDate': '2017-01-01',
#  'endDate': '2017-04-30',
#  'timeUnit': 'month',
#  'results': [{'title': '한글',
#    'keywords': ['한글', 'korean'],
#    'data': [{'period': '2017-01-01', 'ratio': 47.00101},
#     {'period': '2017-02-01', 'ratio': 53.23619},
#     {'period': '2017-03-01', 'ratio': 100},
#     {'period': '2017-04-01', 'ratio': 85.327}]},
#   {'title': '영어',
#    'keywords': ['영어', 'english'],
#    'data': [{'period': '2017-01-01', 'ratio': 40.0881},
#     {'period': '2017-02-01', 'ratio': 36.69942},
#     {'period': '2017-03-01', 'ratio': 52.11792},
#     {'period': '2017-04-01', 'ratio': 44.4595}]}]}

# %%
def get_trend(body):
    url = "https://openapi.naver.com/v1/datalab/search"
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    request.add_header("Content-Type","application/json")
    response = urllib.request.urlopen(request, data=body.encode("utf-8"))

    return json.loads(response.read().decode('utf-8'))

# %%
get_trend(body)
# Out:
# {'startDate': '2017-01-01',
#  'endDate': '2017-04-30',
#  'timeUnit': 'month',
#  'results': [{'title': '한글',
#    'keywords': ['한글', 'korean'],
#    'data': [{'period': '2017-01-01', 'ratio': 47.00101},
#     {'period': '2017-02-01', 'ratio': 53.23619},
#     {'period': '2017-03-01', 'ratio': 100},
#     {'period': '2017-04-01', 'ratio': 85.327}]},
#   {'title': '영어',
#    'keywords': ['영어', 'english'],
#    'data': [{'period': '2017-01-01', 'ratio': 40.0881},
#     {'period': '2017-02-01', 'ratio': 36.69942},
#     {'period': '2017-03-01', 'ratio': 52.11792},
#     {'period': '2017-04-01', 'ratio': 44.4595}]}]}

# %%
body = {
    "startDate":"2019-01-01",
    "endDate":"2019-06-30",
    "timeUnit":"date",
    "keywordGroups":[
        {"groupName":"타다","keywords":["타다","쏘카","vcnc","VCNC"]},
    ],
}

body = json.dumps(body, indent=4, ensure_ascii=False)
print(body)
# Out:
# {
#     "startDate": "2019-01-01",
#     "endDate": "2019-06-30",
#     "timeUnit": "date",
#     "keywordGroups": [
#         {
#             "groupName": "타다",
#             "keywords": [
#                 "타다",
#                 "쏘카",
#                 "vcnc",
#                 "VCNC"
#             ]
#         }
#     ]
# }

# %%
tada_raw_data = get_trend(body)

# %%
tada_raw_data
# Out:
# {'startDate': '2019-01-01',
#  'endDate': '2019-06-30',
#  'timeUnit': 'date',
#  'results': [{'title': '타다',
#    'keywords': ['타다', '쏘카', 'vcnc', 'VCNC'],
#    'data': [{'period': '2019-01-01', 'ratio': 0.82},
#     {'period': '2019-01-02', 'ratio': 1.09367},
#     {'period': '2019-01-03', 'ratio': 1.07254},
#     {'period': '2019-01-04', 'ratio': 1.09213},
#     {'period': '2019-01-05', 'ratio': 1.07815},
#     {'period': '2019-01-06', 'ratio': 0.8945},
#     {'period': '2019-01-07', 'ratio': 1.07903},
#     {'period': '2019-01-08', 'ratio': 1.04184},
#     {'period': '2019-01-09', 'ratio': 1.0545},
#     {'period': '2019-01-10', 'ratio': 1.14319},
#     {'period': '2019-01-11', 'ratio': 1.1072},
#     {'period': '2019-01-12', 'ratio': 0.94798},
#     {'period': '2019-01-13', 'ratio': 0.84553},
#     {'period': '2019-01-14', 'ratio': 1.13581},
#     {'period': '2019-01-15', 'ratio': 1.32849},
#     {'period': '2019-01-16', 'ratio': 1.17664},
#     {'period': '2019-01-17', 'ratio': 1.16993},
#     {'period': '2019-01-18', 'ratio': 1.35072},
#     {'period': '2019-01-19', 'ratio': 1.0907},
#     {'period': '2019-01-20', 'ratio': 0.89934},
#     {'period': '2019-01-21', 'ratio': 1.28305},
#     {'period': '2019-01-22', 'ratio': 1.14924},
#     {'period': '2019-01-23', 'ratio': 1.11623},
#     {'period': '2019-01-24', 'ratio': 1.07804},
#     {'period': '2019-01-25', 'ratio': 1.03172},
#     {'period': '2019-01-26', 'ratio': 0.95876},
#     {'period': '2019-01-27', 'ratio': 0.83244},
#     {'period': '2019-01-28', 'ratio': 1.11293},
#     {'period': '2019-01-29', 'ratio': 1.0326},
#     {'period': '2019-01-30', 'ratio': 1.03073},
#     {'period': '2019-01-31', 'ratio': 1.06033},
#     {'period': '2019-02-01', 'ratio': 1.02457},
#     {'period': '2019-02-02', 'ratio': 0.87579},
#     {'period': '2019-02-03', 'ratio': 0.84784},
#     {'period': '2019-02-04', 'ratio': 0.7761},
#     {'period': '2019-02-05', 'ratio': 0.82176},
#     {'period': '2019-02-06', 'ratio': 0.94644},
#     {'period': '2019-02-07', 'ratio': 1.20602},
#     {'period': '2019-02-08', 'ratio': 1.08069},
#     {'period': '2019-02-09', 'ratio': 1.00751},
#     {'period': '2019-02-10', 'ratio': 0.9241},
#     {'period': '2019-02-11', 'ratio': 1.16266},
#     {'period': '2019-02-12', 'ratio': 1.5237},
#     {'period': '2019-02-13', 'ratio': 1.24904},
#     {'period': '2019-02-14', 'ratio': 1.25576},
#     {'period': '2019-02-15', 'ratio': 1.30362},
#     {'period': '2019-02-16', 'ratio': 1.35611},
#     {'period': '2019-02-17', 'ratio': 1.07617},
#     {'period': '2019-02-18', 'ratio': 4.115},
#     {'period': '2019-02-19', 'ratio': 3.93168},
#     {'period': '2019-02-20', 'ratio': 2.32775},
#     {'period': '2019-02-21', 'ratio': 8.58368},
#     {'period': '2019-02-22', 'ratio': 2.73182},
#     {'period': '2019-02-23', 'ratio': 1.44645},
#     {'period': '2019-02-24', 'ratio': 1.32057},
#     {'period': '2019-02-25', 'ratio': 1.67302},
#     {'period': '2019-02-26', 'ratio': 1.32838},
#     {'period': '2019-02-27', 'ratio': 1.35941},
#     {'period': '2019-02-28', 'ratio': 1.29867},
#     {'period': '2019-03-01', 'ratio': 1.1148},
#     {'period': '2019-03-02', 'ratio': 0.98407},
#     {'period': '2019-03-03', 'ratio': 0.91123},
#     {'period': '2019-03-04', 'ratio': 1.10599},
#     {'period': '2019-03-05', 'ratio': 1.07606},
#     {'period': '2019-03-06', 'ratio': 1.15441},
#     {'period': '2019-03-07', 'ratio': 1.62076},
#     {'period': '2019-03-08', 'ratio': 1.39694},
#     {'period': '2019-03-09', 'ratio': 1.03392},
#     {'period': '2019-03-10', 'ratio': 0.88295},
#     {'period': '2019-03-11', 'ratio': 1.10445},
#     {'period': '2019-03-12', 'ratio': 1.23804},
#     {'period': '2019-03-13', 'ratio': 1.04448},
#     {'period': '2019-03-14', 'ratio': 1.0228},
#     {'period': '2019-03-15', 'ratio': 1.02688},
#     {'period': '2019-03-16', 'ratio': 0.97021},
#     {'period': '2019-03-17', 'ratio': 1.16949},
#     {'period': '2019-03-18', 'ratio': 1.09675},
#     {'period': '2019-03-19', 'ratio': 1.21581},
#     {'period': '2019-03-20', 'ratio': 1.22979},
#     {'period': '2019-03-21', 'ratio': 1.15595},
#     {'period': '2019-03-22', 'ratio': 1.12514},
#     {'period': '2019-03-23', 'ratio': 0.90132},
#     {'period': '2019-03-24', 'ratio': 0.81087},
#     {'period': '2019-03-25', 'ratio': 1.07606},
#     {'period': '2019-03-26', 'ratio': 1.3034},
#     {'period': '2019-03-27', 'ratio': 1.28998},
#     {'period': '2019-03-28', 'ratio': 1.10775},
#     {'period': '2019-03-29', 'ratio': 1.07287},
#     {'period': '2019-03-30', 'ratio': 0.9186},
#     {'period': '2019-03-31', 'ratio': 1.11491},
#     {'period': '2019-04-01', 'ratio': 1.06913},
#     {'period': '2019-04-02', 'ratio': 1.1784},
#     {'period': '2019-04-03', 'ratio': 1.12338},
#     {'period': '2019-04-04', 'ratio': 1.11788},
#     {'period': '2019-04-05', 'ratio': 1.10698},
#     {'period': '2019-04-06', 'ratio': 0.91849},
#     {'period': '2019-04-07', 'ratio': 0.85896},
#     {'period': '2019-04-08', 'ratio': 1.17422},
#     {'period': '2019-04-09', 'ratio': 1.1093},
#     {'period': '2019-04-10', 'ratio': 1.11887},
#     {'period': '2019-04-11', 'ratio': 1.12822},
#     {'period': '2019-04-12', 'ratio': 1.09664},
#     {'period': '2019-04-13', 'ratio': 0.90539},
#     {'period': '2019-04-14', 'ratio': 0.83486},
#     {'period': '2019-04-15', 'ratio': 5.21594},
#     {'period': '2019-04-16', 'ratio': 1.49311},
#     {'period': '2019-04-17', 'ratio': 1.24442},
#     {'period': '2019-04-18', 'ratio': 1.28987},
#     {'period': '2019-04-19', 'ratio': 1.14385},
#     {'period': '2019-04-20', 'ratio': 0.9219},
#     {'period': '2019-04-21', 'ratio': 1.05978},
#     {'period': '2019-04-22', 'ratio': 1.39011},
#     {'period': '2019-04-23', 'ratio': 1.25466},
#     {'period': '2019-04-24', 'ratio': 1.18698},
#     {'period': '2019-04-25', 'ratio': 1.14759},
#     {'period': '2019-04-26', 'ratio': 1.09334},
#     {'period': '2019-04-27', 'ratio': 0.90803},
#     {'period': '2019-04-28', 'ratio': 0.86677},
#     {'period': '2019-04-29', 'ratio': 1.1389},
#     {'period': '2019-04-30', 'ratio': 1.33576},
#     {'period': '2019-05-01', 'ratio': 1.19535},
#     {'period': '2019-05-02', 'ratio': 1.36304},
#     {'period': '2019-05-03', 'ratio': 1.26137},
#     {'period': '2019-05-04', 'ratio': 1.0414},
#     {'period': '2019-05-05', 'ratio': 0.98176},
#     {'period': '2019-05-06', 'ratio': 0.95986},
#     {'period': '2019-05-07', 'ratio': 1.13284},
#     {'period': '2019-05-08', 'ratio': 1.10049},
#     {'period': '2019-05-09', 'ratio': 1.50654},
#     {'period': '2019-05-10', 'ratio': 1.24673},
#     {'period': '2019-05-11', 'ratio': 1.0096},
#     {'period': '2019-05-12', 'ratio': 0.97131},
#     {'period': '2019-05-13', 'ratio': 1.20261},
#     {'period': '2019-05-14', 'ratio': 1.41443},
#     {'period': '2019-05-15', 'ratio': 100},
#     {'period': '2019-05-16', 'ratio': 32.82752},
#     {'period': '2019-05-17', 'ratio': 3.37895},
#     {'period': '2019-05-18', 'ratio': 2.68934},
#     {'period': '2019-05-19', 'ratio': 1.58444},
#     {'period': '2019-05-20', 'ratio': 2.27582},
#     {'period': '2019-05-21', 'ratio': 3.06798},
#     {'period': '2019-05-22', 'ratio': 3.63358},
#     {'period': '2019-05-23', 'ratio': 3.93718},
#     {'period': '2019-05-24', 'ratio': 2.69099},
#     {'period': '2019-05-25', 'ratio': 1.61118},
#     {'period': '2019-05-26', 'ratio': 1.28646},
#     {'period': '2019-05-27', 'ratio': 2.05387},
#     {'period': '2019-05-28', 'ratio': 2.2614},
#     {'period': '2019-05-29', 'ratio': 1.73101},
#     {'period': '2019-05-30', 'ratio': 1.64144},
#     {'period': '2019-05-31', 'ratio': 1.6684},
#     {'period': '2019-06-01', 'ratio': 1.30659},
#     {'period': '2019-06-02', 'ratio': 1.22858},
#     {'period': '2019-06-03', 'ratio': 1.69195},
#     {'period': '2019-06-04', 'ratio': 1.6421},
#     {'period': '2019-06-05', 'ratio': 1.53988},
#     {'period': '2019-06-06', 'ratio': 1.33664},
#     {'period': '2019-06-07', 'ratio': 1.44854},
#     {'period': '2019-06-08', 'ratio': 1.17224},
#     {'period': '2019-06-09', 'ratio': 1.20448},
#     {'period': '2019-06-10', 'ratio': 1.79748},
#     {'period': '2019-06-11', 'ratio': 1.85371},
#     {'period': '2019-06-12', 'ratio': 1.90278},
#     {'period': '2019-06-13', 'ratio': 1.57718},
#     {'period': '2019-06-14', 'ratio': 1.41839},
#     {'period': '2019-06-15', 'ratio': 1.08091},
#     {'period': '2019-06-16', 'ratio': 1.08432},
#     {'period': '2019-06-17', 'ratio': 1.55077},
#     {'period': '2019-06-18', 'ratio': 1.4963},
#     {'period': '2019-06-19', 'ratio': 1.73101},
#     {'period': '2019-06-20', 'ratio': 1.54725},
#     {'period': '2019-06-21', 'ratio': 1.54835},
#     {'period': '2019-06-22', 'ratio': 1.17378},
#     {'period': '2019-06-23', 'ratio': 1.11733},
#     {'period': '2019-06-24', 'ratio': 1.59027},
#     {'period': '2019-06-25', 'ratio': 1.50543},
#     {'period': '2019-06-26', 'ratio': 1.38681},
#     {'period': '2019-06-27', 'ratio': 1.63759},
#     {'period': '2019-06-28', 'ratio': 1.47605},
#     {'period': '2019-06-29', 'ratio': 1.17103},
#     {'period': '2019-06-30', 'ratio': 1.07727}]}]}

# %%
tada_raw_data['results'][0]['data']
# Out:
# [{'period': '2019-01-01', 'ratio': 0.82},
#  {'period': '2019-01-02', 'ratio': 1.09367},
#  {'period': '2019-01-03', 'ratio': 1.07254},
#  {'period': '2019-01-04', 'ratio': 1.09213},
#  {'period': '2019-01-05', 'ratio': 1.07815},
#  {'period': '2019-01-06', 'ratio': 0.8945},
#  {'period': '2019-01-07', 'ratio': 1.07903},
#  {'period': '2019-01-08', 'ratio': 1.04184},
#  {'period': '2019-01-09', 'ratio': 1.0545},
#  {'period': '2019-01-10', 'ratio': 1.14319},
#  {'period': '2019-01-11', 'ratio': 1.1072},
#  {'period': '2019-01-12', 'ratio': 0.94798},
#  {'period': '2019-01-13', 'ratio': 0.84553},
#  {'period': '2019-01-14', 'ratio': 1.13581},
#  {'period': '2019-01-15', 'ratio': 1.32849},
#  {'period': '2019-01-16', 'ratio': 1.17664},
#  {'period': '2019-01-17', 'ratio': 1.16993},
#  {'period': '2019-01-18', 'ratio': 1.35072},
#  {'period': '2019-01-19', 'ratio': 1.0907},
#  {'period': '2019-01-20', 'ratio': 0.89934},
#  {'period': '2019-01-21', 'ratio': 1.28305},
#  {'period': '2019-01-22', 'ratio': 1.14924},
#  {'period': '2019-01-23', 'ratio': 1.11623},
#  {'period': '2019-01-24', 'ratio': 1.07804},
#  {'period': '2019-01-25', 'ratio': 1.03172},
#  {'period': '2019-01-26', 'ratio': 0.95876},
#  {'period': '2019-01-27', 'ratio': 0.83244},
#  {'period': '2019-01-28', 'ratio': 1.11293},
#  {'period': '2019-01-29', 'ratio': 1.0326},
#  {'period': '2019-01-30', 'ratio': 1.03073},
#  {'period': '2019-01-31', 'ratio': 1.06033},
#  {'period': '2019-02-01', 'ratio': 1.02457},
#  {'period': '2019-02-02', 'ratio': 0.87579},
#  {'period': '2019-02-03', 'ratio': 0.84784},
#  {'period': '2019-02-04', 'ratio': 0.7761},
#  {'period': '2019-02-05', 'ratio': 0.82176},
#  {'period': '2019-02-06', 'ratio': 0.94644},
#  {'period': '2019-02-07', 'ratio': 1.20602},
#  {'period': '2019-02-08', 'ratio': 1.08069},
#  {'period': '2019-02-09', 'ratio': 1.00751},
#  {'period': '2019-02-10', 'ratio': 0.9241},
#  {'period': '2019-02-11', 'ratio': 1.16266},
#  {'period': '2019-02-12', 'ratio': 1.5237},
#  {'period': '2019-02-13', 'ratio': 1.24904},
#  {'period': '2019-02-14', 'ratio': 1.25576},
#  {'period': '2019-02-15', 'ratio': 1.30362},
#  {'period': '2019-02-16', 'ratio': 1.35611},
#  {'period': '2019-02-17', 'ratio': 1.07617},
#  {'period': '2019-02-18', 'ratio': 4.115},
#  {'period': '2019-02-19', 'ratio': 3.93168},
#  {'period': '2019-02-20', 'ratio': 2.32775},
#  {'period': '2019-02-21', 'ratio': 8.58368},
#  {'period': '2019-02-22', 'ratio': 2.73182},
#  {'period': '2019-02-23', 'ratio': 1.44645},
#  {'period': '2019-02-24', 'ratio': 1.32057},
#  {'period': '2019-02-25', 'ratio': 1.67302},
#  {'period': '2019-02-26', 'ratio': 1.32838},
#  {'period': '2019-02-27', 'ratio': 1.35941},
#  {'period': '2019-02-28', 'ratio': 1.29867},
#  {'period': '2019-03-01', 'ratio': 1.1148},
#  {'period': '2019-03-02', 'ratio': 0.98407},
#  {'period': '2019-03-03', 'ratio': 0.91123},
#  {'period': '2019-03-04', 'ratio': 1.10599},
#  {'period': '2019-03-05', 'ratio': 1.07606},
#  {'period': '2019-03-06', 'ratio': 1.15441},
#  {'period': '2019-03-07', 'ratio': 1.62076},
#  {'period': '2019-03-08', 'ratio': 1.39694},
#  {'period': '2019-03-09', 'ratio': 1.03392},
#  {'period': '2019-03-10', 'ratio': 0.88295},
#  {'period': '2019-03-11', 'ratio': 1.10445},
#  {'period': '2019-03-12', 'ratio': 1.23804},
#  {'period': '2019-03-13', 'ratio': 1.04448},
#  {'period': '2019-03-14', 'ratio': 1.0228},
#  {'period': '2019-03-15', 'ratio': 1.02688},
#  {'period': '2019-03-16', 'ratio': 0.97021},
#  {'period': '2019-03-17', 'ratio': 1.16949},
#  {'period': '2019-03-18', 'ratio': 1.09675},
#  {'period': '2019-03-19', 'ratio': 1.21581},
#  {'period': '2019-03-20', 'ratio': 1.22979},
#  {'period': '2019-03-21', 'ratio': 1.15595},
#  {'period': '2019-03-22', 'ratio': 1.12514},
#  {'period': '2019-03-23', 'ratio': 0.90132},
#  {'period': '2019-03-24', 'ratio': 0.81087},
#  {'period': '2019-03-25', 'ratio': 1.07606},
#  {'period': '2019-03-26', 'ratio': 1.3034},
#  {'period': '2019-03-27', 'ratio': 1.28998},
#  {'period': '2019-03-28', 'ratio': 1.10775},
#  {'period': '2019-03-29', 'ratio': 1.07287},
#  {'period': '2019-03-30', 'ratio': 0.9186},
#  {'period': '2019-03-31', 'ratio': 1.11491},
#  {'period': '2019-04-01', 'ratio': 1.06913},
#  {'period': '2019-04-02', 'ratio': 1.1784},
#  {'period': '2019-04-03', 'ratio': 1.12338},
#  {'period': '2019-04-04', 'ratio': 1.11788},
#  {'period': '2019-04-05', 'ratio': 1.10698},
#  {'period': '2019-04-06', 'ratio': 0.91849},
#  {'period': '2019-04-07', 'ratio': 0.85896},
#  {'period': '2019-04-08', 'ratio': 1.17422},
#  {'period': '2019-04-09', 'ratio': 1.1093},
#  {'period': '2019-04-10', 'ratio': 1.11887},
#  {'period': '2019-04-11', 'ratio': 1.12822},
#  {'period': '2019-04-12', 'ratio': 1.09664},
#  {'period': '2019-04-13', 'ratio': 0.90539},
#  {'period': '2019-04-14', 'ratio': 0.83486},
#  {'period': '2019-04-15', 'ratio': 5.21594},
#  {'period': '2019-04-16', 'ratio': 1.49311},
#  {'period': '2019-04-17', 'ratio': 1.24442},
#  {'period': '2019-04-18', 'ratio': 1.28987},
#  {'period': '2019-04-19', 'ratio': 1.14385},
#  {'period': '2019-04-20', 'ratio': 0.9219},
#  {'period': '2019-04-21', 'ratio': 1.05978},
#  {'period': '2019-04-22', 'ratio': 1.39011},
#  {'period': '2019-04-23', 'ratio': 1.25466},
#  {'period': '2019-04-24', 'ratio': 1.18698},
#  {'period': '2019-04-25', 'ratio': 1.14759},
#  {'period': '2019-04-26', 'ratio': 1.09334},
#  {'period': '2019-04-27', 'ratio': 0.90803},
#  {'period': '2019-04-28', 'ratio': 0.86677},
#  {'period': '2019-04-29', 'ratio': 1.1389},
#  {'period': '2019-04-30', 'ratio': 1.33576},
#  {'period': '2019-05-01', 'ratio': 1.19535},
#  {'period': '2019-05-02', 'ratio': 1.36304},
#  {'period': '2019-05-03', 'ratio': 1.26137},
#  {'period': '2019-05-04', 'ratio': 1.0414},
#  {'period': '2019-05-05', 'ratio': 0.98176},
#  {'period': '2019-05-06', 'ratio': 0.95986},
#  {'period': '2019-05-07', 'ratio': 1.13284},
#  {'period': '2019-05-08', 'ratio': 1.10049},
#  {'period': '2019-05-09', 'ratio': 1.50654},
#  {'period': '2019-05-10', 'ratio': 1.24673},
#  {'period': '2019-05-11', 'ratio': 1.0096},
#  {'period': '2019-05-12', 'ratio': 0.97131},
#  {'period': '2019-05-13', 'ratio': 1.20261},
#  {'period': '2019-05-14', 'ratio': 1.41443},
#  {'period': '2019-05-15', 'ratio': 100},
#  {'period': '2019-05-16', 'ratio': 32.82752},
#  {'period': '2019-05-17', 'ratio': 3.37895},
#  {'period': '2019-05-18', 'ratio': 2.68934},
#  {'period': '2019-05-19', 'ratio': 1.58444},
#  {'period': '2019-05-20', 'ratio': 2.27582},
#  {'period': '2019-05-21', 'ratio': 3.06798},
#  {'period': '2019-05-22', 'ratio': 3.63358},
#  {'period': '2019-05-23', 'ratio': 3.93718},
#  {'period': '2019-05-24', 'ratio': 2.69099},
#  {'period': '2019-05-25', 'ratio': 1.61118},
#  {'period': '2019-05-26', 'ratio': 1.28646},
#  {'period': '2019-05-27', 'ratio': 2.05387},
#  {'period': '2019-05-28', 'ratio': 2.2614},
#  {'period': '2019-05-29', 'ratio': 1.73101},
#  {'period': '2019-05-30', 'ratio': 1.64144},
#  {'period': '2019-05-31', 'ratio': 1.6684},
#  {'period': '2019-06-01', 'ratio': 1.30659},
#  {'period': '2019-06-02', 'ratio': 1.22858},
#  {'period': '2019-06-03', 'ratio': 1.69195},
#  {'period': '2019-06-04', 'ratio': 1.6421},
#  {'period': '2019-06-05', 'ratio': 1.53988},
#  {'period': '2019-06-06', 'ratio': 1.33664},
#  {'period': '2019-06-07', 'ratio': 1.44854},
#  {'period': '2019-06-08', 'ratio': 1.17224},
#  {'period': '2019-06-09', 'ratio': 1.20448},
#  {'period': '2019-06-10', 'ratio': 1.79748},
#  {'period': '2019-06-11', 'ratio': 1.85371},
#  {'period': '2019-06-12', 'ratio': 1.90278},
#  {'period': '2019-06-13', 'ratio': 1.57718},
#  {'period': '2019-06-14', 'ratio': 1.41839},
#  {'period': '2019-06-15', 'ratio': 1.08091},
#  {'period': '2019-06-16', 'ratio': 1.08432},
#  {'period': '2019-06-17', 'ratio': 1.55077},
#  {'period': '2019-06-18', 'ratio': 1.4963},
#  {'period': '2019-06-19', 'ratio': 1.73101},
#  {'period': '2019-06-20', 'ratio': 1.54725},
#  {'period': '2019-06-21', 'ratio': 1.54835},
#  {'period': '2019-06-22', 'ratio': 1.17378},
#  {'period': '2019-06-23', 'ratio': 1.11733},
#  {'period': '2019-06-24', 'ratio': 1.59027},
#  {'period': '2019-06-25', 'ratio': 1.50543},
#  {'period': '2019-06-26', 'ratio': 1.38681},
#  {'period': '2019-06-27', 'ratio': 1.63759},
#  {'period': '2019-06-28', 'ratio': 1.47605},
#  {'period': '2019-06-29', 'ratio': 1.17103},
#  {'period': '2019-06-30', 'ratio': 1.07727}]

# %%
ratio = [each['ratio'] for each in tada_raw_data['results'][0]['data']]
ratio
# Out:
# [0.82,
#  1.09367,
#  1.07254,
#  1.09213,
#  1.07815,
#  0.8945,
#  1.07903,
#  1.04184,
#  1.0545,
#  1.14319,
#  1.1072,
#  0.94798,
#  0.84553,
#  1.13581,
#  1.32849,
#  1.17664,
#  1.16993,
#  1.35072,
#  1.0907,
#  0.89934,
#  1.28305,
#  1.14924,
#  1.11623,
#  1.07804,
#  1.03172,
#  0.95876,
#  0.83244,
#  1.11293,
#  1.0326,
#  1.03073,
#  1.06033,
#  1.02457,
#  0.87579,
#  0.84784,
#  0.7761,
#  0.82176,
#  0.94644,
#  1.20602,
#  1.08069,
#  1.00751,
#  0.9241,
#  1.16266,
#  1.5237,
#  1.24904,
#  1.25576,
#  1.30362,
#  1.35611,
#  1.07617,
#  4.115,
#  3.93168,
#  2.32775,
#  8.58368,
#  2.73182,
#  1.44645,
#  1.32057,
#  1.67302,
#  1.32838,
#  1.35941,
#  1.29867,
#  1.1148,
#  0.98407,
#  0.91123,
#  1.10599,
#  1.07606,
#  1.15441,
#  1.62076,
#  1.39694,
#  1.03392,
#  0.88295,
#  1.10445,
#  1.23804,
#  1.04448,
#  1.0228,
#  1.02688,
#  0.97021,
#  1.16949,
#  1.09675,
#  1.21581,
#  1.22979,
#  1.15595,
#  1.12514,
#  0.90132,
#  0.81087,
#  1.07606,
#  1.3034,
#  1.28998,
#  1.10775,
#  1.07287,
#  0.9186,
#  1.11491,
#  1.06913,
#  1.1784,
#  1.12338,
#  1.11788,
#  1.10698,
#  0.91849,
#  0.85896,
#  1.17422,
#  1.1093,
#  1.11887,
#  1.12822,
#  1.09664,
#  0.90539,
#  0.83486,
#  5.21594,
#  1.49311,
#  1.24442,
#  1.28987,
#  1.14385,
#  0.9219,
#  1.05978,
#  1.39011,
#  1.25466,
#  1.18698,
#  1.14759,
#  1.09334,
#  0.90803,
#  0.86677,
#  1.1389,
#  1.33576,
#  1.19535,
#  1.36304,
#  1.26137,
#  1.0414,
#  0.98176,
#  0.95986,
#  1.13284,
#  1.10049,
#  1.50654,
#  1.24673,
#  1.0096,
#  0.97131,
#  1.20261,
#  1.41443,
#  100,
#  32.82752,
#  3.37895,
#  2.68934,
#  1.58444,
#  2.27582,
#  3.06798,
#  3.63358,
#  3.93718,
#  2.69099,
#  1.61118,
#  1.28646,
#  2.05387,
#  2.2614,
#  1.73101,
#  1.64144,
#  1.6684,
#  1.30659,
#  1.22858,
#  1.69195,
#  1.6421,
#  1.53988,
#  1.33664,
#  1.44854,
#  1.17224,
#  1.20448,
#  1.79748,
#  1.85371,
#  1.90278,
#  1.57718,
#  1.41839,
#  1.08091,
#  1.08432,
#  1.55077,
#  1.4963,
#  1.73101,
#  1.54725,
#  1.54835,
#  1.17378,
#  1.11733,
#  1.59027,
#  1.50543,
#  1.38681,
#  1.63759,
#  1.47605,
#  1.17103,
#  1.07727]

# %%
date = [each['period'] for each in tada_raw_data['results'][0]['data']]
date
# Out:
# ['2019-01-01',
#  '2019-01-02',
#  '2019-01-03',
#  '2019-01-04',
#  '2019-01-05',
#  '2019-01-06',
#  '2019-01-07',
#  '2019-01-08',
#  '2019-01-09',
#  '2019-01-10',
#  '2019-01-11',
#  '2019-01-12',
#  '2019-01-13',
#  '2019-01-14',
#  '2019-01-15',
#  '2019-01-16',
#  '2019-01-17',
#  '2019-01-18',
#  '2019-01-19',
#  '2019-01-20',
#  '2019-01-21',
#  '2019-01-22',
#  '2019-01-23',
#  '2019-01-24',
#  '2019-01-25',
#  '2019-01-26',
#  '2019-01-27',
#  '2019-01-28',
#  '2019-01-29',
#  '2019-01-30',
#  '2019-01-31',
#  '2019-02-01',
#  '2019-02-02',
#  '2019-02-03',
#  '2019-02-04',
#  '2019-02-05',
#  '2019-02-06',
#  '2019-02-07',
#  '2019-02-08',
#  '2019-02-09',
#  '2019-02-10',
#  '2019-02-11',
#  '2019-02-12',
#  '2019-02-13',
#  '2019-02-14',
#  '2019-02-15',
#  '2019-02-16',
#  '2019-02-17',
#  '2019-02-18',
#  '2019-02-19',
#  '2019-02-20',
#  '2019-02-21',
#  '2019-02-22',
#  '2019-02-23',
#  '2019-02-24',
#  '2019-02-25',
#  '2019-02-26',
#  '2019-02-27',
#  '2019-02-28',
#  '2019-03-01',
#  '2019-03-02',
#  '2019-03-03',
#  '2019-03-04',
#  '2019-03-05',
#  '2019-03-06',
#  '2019-03-07',
#  '2019-03-08',
#  '2019-03-09',
#  '2019-03-10',
#  '2019-03-11',
#  '2019-03-12',
#  '2019-03-13',
#  '2019-03-14',
#  '2019-03-15',
#  '2019-03-16',
#  '2019-03-17',
#  '2019-03-18',
#  '2019-03-19',
#  '2019-03-20',
#  '2019-03-21',
#  '2019-03-22',
#  '2019-03-23',
#  '2019-03-24',
#  '2019-03-25',
#  '2019-03-26',
#  '2019-03-27',
#  '2019-03-28',
#  '2019-03-29',
#  '2019-03-30',
#  '2019-03-31',
#  '2019-04-01',
#  '2019-04-02',
#  '2019-04-03',
#  '2019-04-04',
#  '2019-04-05',
#  '2019-04-06',
#  '2019-04-07',
#  '2019-04-08',
#  '2019-04-09',
#  '2019-04-10',
#  '2019-04-11',
#  '2019-04-12',
#  '2019-04-13',
#  '2019-04-14',
#  '2019-04-15',
#  '2019-04-16',
#  '2019-04-17',
#  '2019-04-18',
#  '2019-04-19',
#  '2019-04-20',
#  '2019-04-21',
#  '2019-04-22',
#  '2019-04-23',
#  '2019-04-24',
#  '2019-04-25',
#  '2019-04-26',
#  '2019-04-27',
#  '2019-04-28',
#  '2019-04-29',
#  '2019-04-30',
#  '2019-05-01',
#  '2019-05-02',
#  '2019-05-03',
#  '2019-05-04',
#  '2019-05-05',
#  '2019-05-06',
#  '2019-05-07',
#  '2019-05-08',
#  '2019-05-09',
#  '2019-05-10',
#  '2019-05-11',
#  '2019-05-12',
#  '2019-05-13',
#  '2019-05-14',
#  '2019-05-15',
#  '2019-05-16',
#  '2019-05-17',
#  '2019-05-18',
#  '2019-05-19',
#  '2019-05-20',
#  '2019-05-21',
#  '2019-05-22',
#  '2019-05-23',
#  '2019-05-24',
#  '2019-05-25',
#  '2019-05-26',
#  '2019-05-27',
#  '2019-05-28',
#  '2019-05-29',
#  '2019-05-30',
#  '2019-05-31',
#  '2019-06-01',
#  '2019-06-02',
#  '2019-06-03',
#  '2019-06-04',
#  '2019-06-05',
#  '2019-06-06',
#  '2019-06-07',
#  '2019-06-08',
#  '2019-06-09',
#  '2019-06-10',
#  '2019-06-11',
#  '2019-06-12',
#  '2019-06-13',
#  '2019-06-14',
#  '2019-06-15',
#  '2019-06-16',
#  '2019-06-17',
#  '2019-06-18',
#  '2019-06-19',
#  '2019-06-20',
#  '2019-06-21',
#  '2019-06-22',
#  '2019-06-23',
#  '2019-06-24',
#  '2019-06-25',
#  '2019-06-26',
#  '2019-06-27',
#  '2019-06-28',
#  '2019-06-29',
#  '2019-06-30']

# %%
plt.figure(figsize=(18,6))
plt.plot(date, ratio)
plt.grid()
plt.xticks(rotation=90)
plt.show()

# %%
tada_pd = pd.DataFrame({'data':ratio}, index=date)
tada_pd.head()
# Out:
#                data
# 2019-01-01  0.82000
# 2019-01-02  1.09367
# 2019-01-03  1.07254
# 2019-01-04  1.09213
# 2019-01-05  1.07815

# %%
vertical_range = tada_pd[tada_pd['data']>30]
vertical_range
# Out:
#                  data
# 2019-05-15  100.00000
# 2019-05-16   32.82752

# %%
vertical_range.index[0], vertical_range.index[-2], vertical_range.index[-1]
# Out:
# ('2019-05-15', '2019-05-15', '2019-05-16')

# %%
vline = [vertical_range.index[0], 
         vertical_range.index[-2], 
         vertical_range.index[-1]]

# %%
plt.figure(figsize=(18,8))
plt.plot(date, ratio)

for each in vline:
    plt.axvline(x=each, color='black')

plt.grid()
plt.xticks('')
plt.show()

# %%
from random import randint

plt.figure(figsize=(18,8))
plt.plot(date, ratio)
for each in vline:
    plt.axvline(x=each, color='black')
    plt.annotate(each, xy=(each, randint(40, 80)), 
                 xytext=(randint(40, 80), randint(40, 80)), size=15, 
                 arrowprops=dict(facecolor='black', shrink=0.04))
    
plt.xticks('')

plt.show()
